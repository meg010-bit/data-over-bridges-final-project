# %% [markdown]
# # **Data Over Bridges**
# ---

# %% [markdown]
# ## Introduction
# This project focuses on choosing a metric to determine the best neighborhood in Pittsburgh. We all agreed that we wanted something that was equally creative yet practical so we could find a data set for each submetric. We ended up choosing sustainability because there are many ways to measure sustainability and determine how a location is eco-friendly. It was somewhat difficult to come up with a metric because all of us wanted to find a submetric that was interesting to us but also had a dataset relevant to our topic. We looked at measuring bestness as “things to do” (restaurants, activities, etc.) but were struggling to find data sets that could fit those submetrics, so that’s how we started to lean towards sustainability.
#
# ---

# %% [markdown]
# ## The Metric
# Our group’s chosen metric is sustainability. Sustainability is a great measure of the quality of an area because a clean, sustainable, eco-friendly environment is key. This allowed us to come up with several unique submetrics because there are so many ways to look at and measure sustainability. You can talk about pollution, but you can also talk about the creative methods an area is using to remain sustainable and environmentally friendly.
#
# The first dataset, "Grow Pittsburgh Food Gardens" contains the grower's identifing information as well as information pertaining to the location of each garden registered with Grow Pittsburgh. We labeled this dataset under the submetric of self-sufficiency because of the produce that the gardens are able to provide to their neighborhoods causing a lessened reliance, however small, on outside food sources.
#
# The second dataset, “POGOH Station Locations” houses information about the POGOH bikeshare system here in Pittsburgh. This was a good data set to use because POGOH has locations in almost every Pittsburgh neighborhood and is a business growing consistently. We’re calling this submetric accessibility because a lot of the data has to do with numbers of bikes and station locations, so the numbers measure how accessible this sustainable transportation method is.
#
# Our third dataset, “City of Pittsburgh Trees,” includes detailed information about the street trees across Pittsburgh, such as their species and location. We used this dataset for our submetric of biodiversity and urban greenery, since trees improve air quality, reduce stormwater runoff, and contribute to healthier neighborhoods. By comparing tree counts across neighborhoods, we aimed to see which areas invest most in green infrastructure and which might need more environmental support.
#
#
# Here we set Jupyter Lab to start digging through our data.

# %%
import pandas as pd
import numpy as np
import fpsnippets

# %% [markdown]
# ---

# %% [markdown]
# ## The Best Neighborhood

# %% [markdown]
# ### Self-Suffuciency through Grow Gardens
# The first aspect of Sustainability that we decided to analyze was Self-Suffuciency. We decided to do this through the presence of grow gardens throughout the neighborhoods of Pittsburgh.
#
# Grow Gardens not only offer fresh food, but they also build communities and teach valuable life skills!
#
# This data set comes from the Grow Pittsburgh on the WPRDC.

# %%
gardens = pd.read_csv("https://data.wprdc.org/dataset/0d8c9708-3f01-48c4-adff-04d29825c9a2/resource/dbdfcb3e-8fa5-4468-9b05-f69562798f7a/download/grow-pgh-food-gardens.csv")
gardens.head(80)
# Out:
#                                          urban_grower  grower_id  \
# 0                                      Angora Gardens        584
# 1                                  Everybody's Garden        586
# 2                                    EvGard Extension        587
# 3                        Glen Hazel Communiuty Garden        588
# 4                                     Grow Pittsburgh        589
# ..                                                ...        ...
# 75                        Penn Hills Community Garden        734
# 76  Stanton Heights Allegheny Cemetery Community G...        735
# 77        The Harry Orlando Memorial Community Garden        736
# 78                                 The Octopus Garden        738
# 79                     Tustin Street Community Garden        739
#
#                                          category  \
# 0                  sustainability-fund-site|other
# 1                  sustainability-fund-site|other
# 2                                           other
# 3                                           other
# 4                            grow-pittsburgh-site
# ..                                            ...
# 75  allegheny-grows-site|sustainability-fund-site
# 76                       sustainability-fund-site
# 77                               community-garden
# 78                               community-garden
# 79                           allegheny-grows-site
#
#                                                   url  \
# 0   https://www.growpittsburgh.org/directory/garde...
# 1   https://www.growpittsburgh.org/directory/garde...
# 2   https://www.growpittsburgh.org/directory/garde...
# 3   https://www.growpittsburgh.org/directory/garde...
# 4   https://www.growpittsburgh.org/directory/garde...
# ..                                                ...
# 75  https://www.growpittsburgh.org/directory/garde...
# 76  https://www.growpittsburgh.org/directory/garde...
# 77  https://www.growpittsburgh.org/directory/garde...
# 78  https://www.growpittsburgh.org/directory/garde...
# 79  https://www.growpittsburgh.org/directory/garde...
#
#                       street_address        city         state  zip_code  \
# 0                        3 Muse Lane   White Oak  Pennsylvania   15131.0
# 1          301 West Elizabeth Street  Pittsburgh  Pennsylvania   15207.0
# 2                                NaN  Pittsburgh  Pennsylvania   15201.0
# 3   Johnston Avenue at Roselle Drive  Pittsburgh  Pennsylvania   15207.0
# 4           6587 Hamilton Avenue #2W  Pittsburgh  Pennsylvania   15206.0
# ..                               ...         ...           ...       ...
# 75               1162 Jefferson Road  Penn Hills  Pennsylvania   15235.0
# 76                    Stanton Avenue  Pittsburgh  Pennsylvania   15201.0
# 77                   2205 5th Avenue  Pittsburgh  Pennsylvania   15219.0
# 78               133 S. Aiken Avenue  Pittsburgh  Pennsylvania   15206.0
# 79                2021 Tustin Street  Pittsburgh  Pennsylvania   15219.0
#
#    country   latitude  longitude
# 0       US  40.404686 -79.862095
# 1       US  40.406546 -79.945442
# 2       US  40.406377 -79.945559
# 3       US  40.406040 -79.931253
# 4       US  40.458481 -79.911381
# ..     ...        ...        ...
# 75      US  40.447638 -79.798817
# 76      US  40.473711 -79.961237
# 77      US  40.438247 -79.973943
# 78      US  40.463591 -79.936771
# 79      US  40.436569 -79.977099
#
# [80 rows x 11 columns]

# %% [markdown]
# This data is not very helpful on its own, but we can use the longitude and latitude to find which neighborhoods each grow garden is located in. Through the use of fpsnippets, each coordinate represents a spot within a neighborhood. This is how we can figure out which neighborhood has the most grow gardens.

# %%
gardens_adj = pd.DataFrame(gardens)

neighborhoods_list = []

for index, row in gardens.iterrows():
    lat = row['latitude']
    long = row['longitude']
    neighborhoods_list.append(fpsnippets.geo_to_neighborhood(lat, long))

list_to_series = pd.Series(neighborhoods_list, name = 'neighborhoods')

gardens_adj['neighborhoods'] = list_to_series

gardens_adj.head(80)
# Out:
#                                          urban_grower  grower_id  \
# 0                                      Angora Gardens        584
# 1                                  Everybody's Garden        586
# 2                                    EvGard Extension        587
# 3                        Glen Hazel Communiuty Garden        588
# 4                                     Grow Pittsburgh        589
# ..                                                ...        ...
# 75                        Penn Hills Community Garden        734
# 76  Stanton Heights Allegheny Cemetery Community G...        735
# 77        The Harry Orlando Memorial Community Garden        736
# 78                                 The Octopus Garden        738
# 79                     Tustin Street Community Garden        739
#
#                                          category  \
# 0                  sustainability-fund-site|other
# 1                  sustainability-fund-site|other
# 2                                           other
# 3                                           other
# 4                            grow-pittsburgh-site
# ..                                            ...
# 75  allegheny-grows-site|sustainability-fund-site
# 76                       sustainability-fund-site
# 77                               community-garden
# 78                               community-garden
# 79                           allegheny-grows-site
#
#                                                   url  \
# 0   https://www.growpittsburgh.org/directory/garde...
# 1   https://www.growpittsburgh.org/directory/garde...
# 2   https://www.growpittsburgh.org/directory/garde...
# 3   https://www.growpittsburgh.org/directory/garde...
# 4   https://www.growpittsburgh.org/directory/garde...
# ..                                                ...
# 75  https://www.growpittsburgh.org/directory/garde...
# 76  https://www.growpittsburgh.org/directory/garde...
# 77  https://www.growpittsburgh.org/directory/garde...
# 78  https://www.growpittsburgh.org/directory/garde...
# 79  https://www.growpittsburgh.org/directory/garde...
#
#                       street_address        city         state  zip_code  \
# 0                        3 Muse Lane   White Oak  Pennsylvania   15131.0
# 1          301 West Elizabeth Street  Pittsburgh  Pennsylvania   15207.0
# 2                                NaN  Pittsburgh  Pennsylvania   15201.0
# 3   Johnston Avenue at Roselle Drive  Pittsburgh  Pennsylvania   15207.0
# 4           6587 Hamilton Avenue #2W  Pittsburgh  Pennsylvania   15206.0
# ..                               ...         ...           ...       ...
# 75               1162 Jefferson Road  Penn Hills  Pennsylvania   15235.0
# 76                    Stanton Avenue  Pittsburgh  Pennsylvania   15201.0
# 77                   2205 5th Avenue  Pittsburgh  Pennsylvania   15219.0
# 78               133 S. Aiken Avenue  Pittsburgh  Pennsylvania   15206.0
# 79                2021 Tustin Street  Pittsburgh  Pennsylvania   15219.0
#
#    country   latitude  longitude          neighborhoods
# 0       US  40.404686 -79.862095         Swisshelm Park
# 1       US  40.406546 -79.945442              Hazelwood
# 2       US  40.406377 -79.945559              Hazelwood
# 3       US  40.406040 -79.931253             Glen Hazel
# 4       US  40.458481 -79.911381                Larimer
# ..     ...        ...        ...                    ...
# 75      US  40.447638 -79.798817             East Hills
# 76      US  40.473711 -79.961237  Central Lawrenceville
# 77      US  40.438247 -79.973943           West Oakland
# 78      US  40.463591 -79.936771             Bloomfield
# 79      US  40.436569 -79.977099                  Bluff
#
# [80 rows x 12 columns]

# %% [markdown]
# This data shows a bit of a clear picture, but it still has grow gardens with no neighborhood associated with them. Let's group this data together by neighborhood to show which neighborhoods have the most gardens.

# %%
gardens_by_neighborhood = gardens_adj.groupby("neighborhoods").count().loc[:,"urban_grower"].sort_values(ascending=False)
gardens_by_neighborhood[:10]
# Out:
# neighborhoods
# Point Breeze             4
# Garfield                 4
# Hazelwood                3
# Larimer                  3
# Central Lawrenceville    3
# East Liberty             3
# Lincoln Place            3
# South Oakland            3
# West Oakland             3
# Middle Hill              3
# Name: urban_grower, dtype: int64

# %% [markdown]
# This is a good representation of which neighborhoods have the most grow gardens, but we can show a greater set through a bar graph.

# %%
gardens_by_neighborhood.plot.bar(title = "Number of Grow Gardens by Neighborhood in Pittsburgh", figsize = (10,4))
# Out:
# <Axes: title={'center': 'Number of Grow Gardens by Neighborhood in Pittsburgh'}, xlabel='neighborhoods'>

# %% [markdown]
# ### Accessibility through POGOH
# The second aspect of Sustainability that we decided to analyze was Accessibility. We decided to do this through the variety of POGOH station locations throughout the neighborhoods of Pittsburgh.
#
# POGOH is the bike share service offered throughout pittsburgh allowing users to rent regular and e-assist bikes!
#
# This data set comes from the POGOH on the WPRDC.

# %%
pogoh = pd.read_csv('pogoh.tsv',sep='\t')
pogoh.head(60)
# Out:
#     _id  Id                                      Name  Total Docks   Latitude  \
# 0     1   1                  Pierce St & Summerlea St           19  40.456507
# 1     2   2       Eliza Furnace Trail & Swineburne St           15  40.425800
# 2     3   3                   Centre Ave & Addison St           15  40.444600
# 3     4   4         Burns White Center at 3 Crossings           15  40.456400
# 4     5   5                         Allegheny Station           19  40.448301
# 5     6   6                        10th St & Penn Ave           15  40.444653
# 6     7   7                    Liberty Ave & Gross St           15  40.459588
# 7     8   8                                Glasshouse           15  40.432900
# 8     9   9               South Side Trail & S 4th St           15  40.431336
# 9    10  10                   Zulema St & Coltart Ave           19  40.436055
# 10   11  11              Ellsworth Ave & N Neville St           15  40.448203
# 11   12  12              O'Hara St & University Place           23  40.445117
# 12   13  13                S Bouquet Ave & Sennott St           23  40.441638
# 13   14  14                 Tioga St & N Homewood Ave           15  40.454226
# 14   15  15                        Ivy St & Walnut St           19  40.451781
# 15   16  16      Penn Ave & Putnam St (Bakery Square)           19  40.455900
# 16   17  17                   Taylor St & Liberty Ave           15  40.462778
# 17   18  18                        21st St & Penn Ave           19  40.451800
# 18   19  19                       42nd St & Butler St           15  40.470221
# 19   20  20    Boulevard of the Allies & Parkview Ave           23  40.434400
# 20   21  21                  Liberty Ave & Stanwix St           15  40.441200
# 21   22  22                Forbes Ave & Market Square           19  40.440773
# 22   23  23  North Shore Trail & Fort Duquesne Bridge           23  40.445800
# 23   24  24                        Penn Ave & 33rd St           11  40.462000
# 24   25  25                 Penn Ave & S Whitfield St           15  40.461600
# 25   26  26  S 27th St & Sidney St. (Southside Works)           23  40.427991
# 26   27  27      W Station Square Dr & Bessemer Court           15  40.433800
# 27   28  28                  Fifth Ave & S Bouquet St           23  40.442200
# 28   29  29             Filmore St & S Bellefield Ave           27  40.445145
# 29   30  30                 Shady Ave & Ellsworth Ave           15  40.459181
# 30   31  31                          First Ave & B St           15  40.435922
# 31   32  32                      Ross St & Fourth Ave           15  40.437701
# 32   33  33             Schenley Dr & Schenley Dr Ext           19  40.442371
# 33   34  34               N Dithridge St & Centre Ave           19  40.451281
# 34   35  35                       Butler St & 36th St           15  40.465264
# 35   36  36                  Penn Ave & S Pacific Ave           15  40.464600
# 36   37  37                 S Negley Ave & Centre Ave           15  40.457316
# 37   38  38                Allequippa St & Darragh St           23  40.443591
# 38   39  39                   S 12th St & E Carson St           19  40.428600
# 39   40  40                         Penn Ave & 7th St           19  40.443310
# 40   41  41                     S 22nd St & Sidney St           19  40.429212
# 41   42  42                  Second Ave & Tecumseh St           19  40.408857
# 42   43  43                       Eliza St & Lytle St           15  40.413481
# 43   44  44                  Hamilton Ave & Fifth Ave           15  40.457570
# 44   45  45             N Braddock Ave & Hamilton Ave           15  40.453010
# 45   46  46               Bennett St & N Homewood Ave           15  40.456622
# 46   47  47                        17th St & Penn Ave           19  40.449626
# 47   48  48               Centre Ave & S Millvale Ave           19  40.453211
# 48   49  49                  Technology Dr & Bates St           23  40.430513
# 49   50  50                      Atwood St & Bates St           19  40.437987
# 50   51  51                  Coltart Ave & Forbes Ave           18  40.439012
# 51   52  52                   Bedford Ave & Memory Ln           19  40.448361
# 52   53  53                   Centre Ave & Heldman St           19  40.442841
# 53   54  54                   W Ohio St & Brighton Rd           19  40.452467
# 54   55  55            Brighton Rd & Pennsylvania Ave           19  40.456402
# 55   56  56                  Rosetta St & N Aiken Ave           15  40.467018
# 56   57  57                       52nd St & Butler St           19  40.480283
# 57   58  58                  W North Ave & Federal St           19  40.455268
# 58   59  59       Forbes Ave at TCS Hall (CMU Campus)           19  40.444654
# 59   60  60                   Wilkinsburg Park & Ride           19  40.446908
#
#     Longitude
# 0  -79.932331
# 1  -79.953400
# 2  -79.978300
# 3  -79.980000
# 4  -80.018007
# 5  -79.996074
# 6  -79.945204
# 7  -80.003000
# 8  -79.995106
# 9  -79.956827
# 10 -79.947507
# 11 -79.957118
# 12 -79.955764
# 13 -79.897544
# 14 -79.932253
# 15 -79.915300
# 16 -79.950868
# 17 -79.983300
# 18 -79.960380
# 19 -79.951900
# 20 -80.004800
# 21 -80.003312
# 22 -80.009100
# 23 -79.968300
# 24 -79.925700
# 25 -79.966296
# 26 -80.004700
# 27 -79.957600
# 28 -79.951083
# 29 -79.921996
# 30 -79.997551
# 31 -79.996481
# 32 -79.951688
# 33 -79.952982
# 34 -79.965652
# 35 -79.939900
# 36 -79.934331
# 37 -79.965456
# 38 -79.986371
# 39 -79.999996
# 40 -79.974535
# 41 -79.943684
# 42 -79.948254
# 43 -79.909952
# 44 -79.891204
# 45 -79.897503
# 46 -79.985918
# 47 -79.947761
# 48 -79.959989
# 49 -79.953705
# 50 -79.960292
# 51 -79.978268
# 52 -79.981616
# 53 -80.013872
# 54 -80.015393
# 55 -79.935232
# 56 -79.954287
# 57 -80.007123
# 58 -79.947535
# 59 -79.888645

# %% [markdown]
# While this data tells us the streets and coordinates of the stations, it does not directly tell us the neighborhoods, so let's use fpsnippets to locate the neighborhoods where the stations are located.

# %%
pogoh_adj = pd.DataFrame(pogoh)

neighborhoods_list = []

for index, row in pogoh.iterrows():
    lat = row['Latitude']
    long = row['Longitude']
    neighborhoods_list.append(fpsnippets.geo_to_neighborhood(lat, long))

list_to_series = pd.Series(neighborhoods_list, name = 'neighborhoods')

pogoh_adj['neighborhoods'] = list_to_series

pogoh_adj.head(60)
# Out:
#     _id  Id                                      Name  Total Docks   Latitude  \
# 0     1   1                  Pierce St & Summerlea St           19  40.456507
# 1     2   2       Eliza Furnace Trail & Swineburne St           15  40.425800
# 2     3   3                   Centre Ave & Addison St           15  40.444600
# 3     4   4         Burns White Center at 3 Crossings           15  40.456400
# 4     5   5                         Allegheny Station           19  40.448301
# 5     6   6                        10th St & Penn Ave           15  40.444653
# 6     7   7                    Liberty Ave & Gross St           15  40.459588
# 7     8   8                                Glasshouse           15  40.432900
# 8     9   9               South Side Trail & S 4th St           15  40.431336
# 9    10  10                   Zulema St & Coltart Ave           19  40.436055
# 10   11  11              Ellsworth Ave & N Neville St           15  40.448203
# 11   12  12              O'Hara St & University Place           23  40.445117
# 12   13  13                S Bouquet Ave & Sennott St           23  40.441638
# 13   14  14                 Tioga St & N Homewood Ave           15  40.454226
# 14   15  15                        Ivy St & Walnut St           19  40.451781
# 15   16  16      Penn Ave & Putnam St (Bakery Square)           19  40.455900
# 16   17  17                   Taylor St & Liberty Ave           15  40.462778
# 17   18  18                        21st St & Penn Ave           19  40.451800
# 18   19  19                       42nd St & Butler St           15  40.470221
# 19   20  20    Boulevard of the Allies & Parkview Ave           23  40.434400
# 20   21  21                  Liberty Ave & Stanwix St           15  40.441200
# 21   22  22                Forbes Ave & Market Square           19  40.440773
# 22   23  23  North Shore Trail & Fort Duquesne Bridge           23  40.445800
# 23   24  24                        Penn Ave & 33rd St           11  40.462000
# 24   25  25                 Penn Ave & S Whitfield St           15  40.461600
# 25   26  26  S 27th St & Sidney St. (Southside Works)           23  40.427991
# 26   27  27      W Station Square Dr & Bessemer Court           15  40.433800
# 27   28  28                  Fifth Ave & S Bouquet St           23  40.442200
# 28   29  29             Filmore St & S Bellefield Ave           27  40.445145
# 29   30  30                 Shady Ave & Ellsworth Ave           15  40.459181
# 30   31  31                          First Ave & B St           15  40.435922
# 31   32  32                      Ross St & Fourth Ave           15  40.437701
# 32   33  33             Schenley Dr & Schenley Dr Ext           19  40.442371
# 33   34  34               N Dithridge St & Centre Ave           19  40.451281
# 34   35  35                       Butler St & 36th St           15  40.465264
# 35   36  36                  Penn Ave & S Pacific Ave           15  40.464600
# 36   37  37                 S Negley Ave & Centre Ave           15  40.457316
# 37   38  38                Allequippa St & Darragh St           23  40.443591
# 38   39  39                   S 12th St & E Carson St           19  40.428600
# 39   40  40                         Penn Ave & 7th St           19  40.443310
# 40   41  41                     S 22nd St & Sidney St           19  40.429212
# 41   42  42                  Second Ave & Tecumseh St           19  40.408857
# 42   43  43                       Eliza St & Lytle St           15  40.413481
# 43   44  44                  Hamilton Ave & Fifth Ave           15  40.457570
# 44   45  45             N Braddock Ave & Hamilton Ave           15  40.453010
# 45   46  46               Bennett St & N Homewood Ave           15  40.456622
# 46   47  47                        17th St & Penn Ave           19  40.449626
# 47   48  48               Centre Ave & S Millvale Ave           19  40.453211
# 48   49  49                  Technology Dr & Bates St           23  40.430513
# 49   50  50                      Atwood St & Bates St           19  40.437987
# 50   51  51                  Coltart Ave & Forbes Ave           18  40.439012
# 51   52  52                   Bedford Ave & Memory Ln           19  40.448361
# 52   53  53                   Centre Ave & Heldman St           19  40.442841
# 53   54  54                   W Ohio St & Brighton Rd           19  40.452467
# 54   55  55            Brighton Rd & Pennsylvania Ave           19  40.456402
# 55   56  56                  Rosetta St & N Aiken Ave           15  40.467018
# 56   57  57                       52nd St & Butler St           19  40.480283
# 57   58  58                  W North Ave & Federal St           19  40.455268
# 58   59  59       Forbes Ave at TCS Hall (CMU Campus)           19  40.444654
# 59   60  60                   Wilkinsburg Park & Ride           19  40.446908
#
#     Longitude              neighborhoods
# 0  -79.932331                  Shadyside
# 1  -79.953400                  Hazelwood
# 2  -79.978300                Middle Hill
# 3  -79.980000             Strip District
# 4  -80.018007                North Shore
# 5  -79.996074  Central Business District
# 6  -79.945204                 Bloomfield
# 7  -80.003000  Central Business District
# 8  -79.995106           South Side Flats
# 9  -79.956827            Central Oakland
# 10 -79.947507                  Shadyside
# 11 -79.957118              North Oakland
# 12 -79.955764            Central Oakland
# 13 -79.897544             Homewood South
# 14 -79.932253                  Shadyside
# 15 -79.915300                  Shadyside
# 16 -79.950868                 Bloomfield
# 17 -79.983300             Strip District
# 18 -79.960380      Central Lawrenceville
# 19 -79.951900            Central Oakland
# 20 -80.004800  Central Business District
# 21 -80.003312  Central Business District
# 22 -80.009100                North Shore
# 23 -79.968300        Lower Lawrenceville
# 24 -79.925700               East Liberty
# 25 -79.966296           South Side Flats
# 26 -80.004700           Mount Washington
# 27 -79.957600               West Oakland
# 28 -79.951083              North Oakland
# 29 -79.921996                  Shadyside
# 30 -79.997551  Central Business District
# 31 -79.996481  Central Business District
# 32 -79.951688              North Oakland
# 33 -79.952982              North Oakland
# 34 -79.965652        Lower Lawrenceville
# 35 -79.939900                 Bloomfield
# 36 -79.934331                  Shadyside
# 37 -79.965456            Terrace Village
# 38 -79.986371           South Side Flats
# 39 -79.999996  Central Business District
# 40 -79.974535           South Side Flats
# 41 -79.943684                  Hazelwood
# 42 -79.948254                  Hazelwood
# 43 -79.909952                    Larimer
# 44 -79.891204             Homewood South
# 45 -79.897503             Homewood South
# 46 -79.985918             Strip District
# 47 -79.947761                 Bloomfield
# 48 -79.959989              South Oakland
# 49 -79.953705            Central Oakland
# 50 -79.960292            Central Oakland
# 51 -79.978268          Bedford Dwellings
# 52 -79.981616           Crawford-Roberts
# 53 -80.013872           Allegheny Center
# 54 -80.015393          Central Northside
# 55 -79.935232                   Garfield
# 56 -79.954287        Upper Lawrenceville
# 57 -80.007123           Allegheny Center
# 58 -79.947535              North Oakland
# 59 -79.888645             Homewood South

# %% [markdown]
# Now that we have the neighborhoods of the stations we can group the stations together by neighborhood and see which Pittsburgh neighborhood has the most stations.

# %%
stations_by_neighborhood = pogoh_adj.groupby("neighborhoods").count().loc[:,"_id"].sort_values(ascending=False)
stations_by_neighborhood[:10]
# Out:
# neighborhoods
# Central Business District    7
# Shadyside                    6
# Central Oakland              5
# North Oakland                5
# Bloomfield                   4
# Homewood South               4
# South Side Flats             4
# Strip District               3
# Hazelwood                    3
# North Shore                  2
# Name: _id, dtype: int64

# %% [markdown]
# We can even take this one step further by creating a bar graph to show a larger set of neighborhoods and their number of POGOH stations.

# %%
stations_by_neighborhood.plot.bar(title = "Number of Stations per Neighborhood", figsize = (10,6))
# Out:
# <Axes: title={'center': 'Number of Stations per Neighborhood'}, xlabel='neighborhoods'>

# %% [markdown]
# ### Biodiversity through City of Pittsburgh Trees

# %%
# !pip install geopandas
# !pip install pandas matplotlib
# !pip install seaborn
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas in /ihome/cmpinf0010_2025f/rra40/.local/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: numpy>=1.24 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from geopandas) (2.3.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /ihome/cmpinf0010_2025f/rra40/.local/lib/python3.11/site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=2.0.0 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from geopandas) (2.3.1)
# Requirement already satisfied: pyproj>=3.5.0 in /ihome/cmpinf0010_2025f/rra40/.local/lib/python3.11/site-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /ihome/cmpinf0010_2025f/rra40/.local/lib/python3.11/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: matplotlib in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: numpy>=1.23.2 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /ihome/cmpinf0010_2025f/rra40/.local/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pandas>=1.2 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in /ihome/cmpinf0010_2025f/rra40/.local/lib/python3.11/site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /ihome/cmpinf0010_2025f/rra40/.local/lib/python3.11/site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from folium) (2.3.1)
# Requirement already satisfied: requests in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /ihome/cmpinf0010_2025f/rra40/.local/lib/python3.11/site-packages (from folium) (2025.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /software/rhel9/manual/install/jupyterhub/hub.5.2.1/lib/python3.11/site-packages (from requests->folium) (2025.8.3)

# %%
import pandas as pd

df = pd.read_csv("city_trees.csv", low_memory=False)

df.head(10)
# Out:
#    _id          id address_number         street               common_name  \
# 0    1   754166088           7428  MONTICELLO ST                     Stump
# 1    2  1946899269            220     BALVER AVE        Linden: Littleleaf
# 2    3  1431517397           2822      SIDNEY ST                Maple: Red
# 3    4   994063598            608     SUISMON ST            Maple: Freeman
# 4    5  1591838573           1135   N NEGLEY AVE             Maple: Norway
# 5    6  1333224197           5550      BRYANT ST                  Oak: Pin
# 6    7   239290336           5503      BRYANT ST  Dogwood: Corneliancherry
# 7    8  1233652274           1207       KING AVE             Maple: Norway
# 8    9  1477030894           1201       KING AVE             Maple: Norway
# 9   10  1484901843           1456    WOODBINE ST             Maple: Norway
#
#      scientific_name  height  width  growth_space_length  growth_space_width  \
# 0              Stump     0.0    0.0                 10.0                 2.0
# 1      Tilia cordata     0.0    0.0                 99.0                99.0
# 2        Acer rubrum    22.0    6.0                  6.0                 3.0
# 3   Acer x freemanii    25.0   10.0                  3.0                 3.0
# 4   Acer platanoides    52.0   13.0                 99.0                99.0
# 5  Quercus palustris    45.0   18.0                 35.0                 3.0
# 6         Cornus mas     8.0    4.0                 99.0                 3.0
# 7   Acer platanoides    27.0   10.0                 30.0                 3.0
# 8   Acer platanoides    35.0   12.0                  3.0                 3.0
# 9   Acer platanoides     NaN    NaN                  NaN                 NaN
#
#    ...      neighborhood  council_district  ward         tract  \
# 0  ...    Homewood North               9.0  13.0  4.200313e+10
# 1  ...           Oakwood               2.0  28.0  4.200356e+10
# 2  ...  South Side Flats               3.0  16.0  4.200316e+10
# 3  ...    East Allegheny               1.0  23.0  4.200356e+10
# 4  ...     Highland Park               7.0  11.0  4.200311e+10
# 5  ...     Highland Park               7.0  11.0  4.200311e+10
# 6  ...     Highland Park               7.0  11.0  4.200311e+10
# 7  ...     Highland Park               7.0  11.0  4.200311e+10
# 8  ...     Highland Park               7.0  11.0  4.200311e+10
# 9  ...   Stanton Heights               7.0  10.0  4.200310e+10
#
#   public_works_division pli_division  police_zone  fire_zone   latitude  \
# 0                   2.0         13.0          5.0       3-17  40.458169
# 1                   5.0         28.0          6.0       1-19  40.429269
# 2                   3.0         16.0          3.0       4-24  40.426797
# 3                   1.0         23.0          1.0        1-6  40.455503
# 4                   2.0         11.0          5.0        3-9  40.476667
# 5                   2.0         11.0          5.0        3-9  40.477496
# 6                   2.0         11.0          5.0        3-9  40.478403
# 7                   2.0         11.0          5.0        3-9  40.478404
# 8                   2.0         11.0          5.0        3-9  40.478314
# 9                   2.0         10.0          5.0        3-7  40.485240
#
#    longitude
# 0 -79.889724
# 1 -80.067868
# 2 -79.965035
# 3 -79.999276
# 4 -79.924106
# 5 -79.924568
# 6 -79.925985
# 7 -79.926126
# 8 -79.926161
# 9 -79.936390
#
# [10 rows x 59 columns]

# %% [markdown]
# This dataset is a 59-column CSV file containing detailed information about city trees, including their ID, location, species, and physical attributes such as height, width, and growth space measurements.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Suppress FutureWarnings from seaborn
warnings.simplefilter(action='ignore', category=FutureWarning)

# Load the city trees CSV
df = pd.read_csv("city_trees.csv", low_memory=False)

# Count trees per neighborhood
tree_counts = df['neighborhood'].value_counts()

# Plot the bar chart
plt.figure(figsize=(18,6))
sns.barplot(
    x=tree_counts.index,
    y=tree_counts.values,
    hue=tree_counts.index,    
    palette="Spectral",
    legend=False                   
)
plt.title("Tree Count by Neighborhood")
plt.ylabel("Tree Count")
plt.xlabel("Neighborhood")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("city_trees.csv", low_memory=False)
top10 = df['neighborhood'].value_counts().head(10)

plt.figure(figsize=(12,6))
sns.barplot(x=top10.index, y=top10.values, palette="Spectral")
plt.title("Top 10 Neighborhoods by Tree Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# This bar chart shows the distribution of tree counts across Pittsburgh neighborhoods. Squirrel Hill South has the highest number of trees, followed by Frick Park and Squirrel Hill North, while many smaller neighborhoods have significantly fewer trees. The plot highlights how tree density is heavily concentrated in a few large, green neighborhoods.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Across the three sustainability indicators (POGOH station availability, Grow Gardens, and tree coverage), **Bloomfield** emerges as the most balanced and sustainable neighborhood. While it does not rank first in any single category, it consistently performs near the top across all three metrics. This strong overall presence in transit access, food resilience, and environmental greenery makes Bloomfield the most holistically sustainable neighborhood among those analyzed.
