# %% [markdown]
# ## Introduction

# %%
import pandas as pd

# %% [markdown]
# We ended up choosing sustainability as our metric because there are many ways you can define sustainability within an area. It can mean the activism of a specific neighborhood about environmental concerns, but it can allso include preventative measures and environmentally friendly options that areas have. We were all able to find a system or submetric with a data sets that both appealed to our own interests and was relevant to our group metric. We first looked into doing entertainment or "things to do" as a way of measuring the best neighborhood, but it was much more difficult to find a data set that fit that metric, and we determined that sustainability was the best measure for our group as a whole.

# %% [markdown]
# ## The Metric

# %% [markdown]
# As we said before, our group's chosen metric was sustainability. It was a great metric because it was unique yet relevant and important. My submetric that I used was accessbility of environmentally friendly transportation. As we know, bikes are considered one of the many ways to self-transport in an eco-friendly way. I found a way to measure this through a dataset about the POGOH bikes here in Pittsburgh. The data set provides bike station locations (both through location name and latitude/longitude) and number of docks.
# (this will also include Meg's and Rujuta's metrics and data sets)

# %%
# Reads and displays the original Data Set
pogoh = pd.read_csv('pogoh.tsv',sep='\t')
pogoh.head(60)
# Out:
#     Id                                      Name  Total Docks   Latitude  \
# 0    1                  Pierce St & Summerlea St           19  40.456507
# 1    2       Eliza Furnace Trail & Swineburne St           15  40.425800
# 2    3                   Centre Ave & Addison St           15  40.444600
# 3    4         Burns White Center at 3 Crossings           15  40.456400
# 4    5                         Allegheny Station           19  40.448301
# 5    6                        10th St & Penn Ave           15  40.444653
# 6    7                    Liberty Ave & Gross St           15  40.459588
# 7    8                                Glasshouse           15  40.432900
# 8    9               South Side Trail & S 4th St           15  40.431336
# 9   10                   Zulema St & Coltart Ave           19  40.436055
# 10  11              Ellsworth Ave & N Neville St           15  40.448203
# 11  12              O'Hara St & University Place           23  40.445117
# 12  13                S Bouquet Ave & Sennott St           23  40.441638
# 13  14                 Tioga St & N Homewood Ave           15  40.454226
# 14  15                        Ivy St & Walnut St           19  40.451781
# 15  16      Penn Ave & Putnam St (Bakery Square)           19  40.455900
# 16  17                   Taylor St & Liberty Ave           15  40.462778
# 17  18                        21st St & Penn Ave           19  40.451800
# 18  19                       42nd St & Butler St           15  40.470221
# 19  20    Boulevard of the Allies & Parkview Ave           23  40.434400
# 20  21                  Liberty Ave & Stanwix St           15  40.441200
# 21  22                Forbes Ave & Market Square           19  40.440773
# 22  23  North Shore Trail & Fort Duquesne Bridge           23  40.445800
# 23  24                        Penn Ave & 33rd St           11  40.462000
# 24  25                 Penn Ave & S Whitfield St           15  40.461600
# 25  26  S 27th St & Sidney St. (Southside Works)           23  40.427991
# 26  27      W Station Square Dr & Bessemer Court           15  40.433800
# 27  28                  Fifth Ave & S Bouquet St           23  40.442200
# 28  29             Filmore St & S Bellefield Ave           27  40.445145
# 29  30                 Shady Ave & Ellsworth Ave           15  40.459181
# 30  31                          First Ave & B St           15  40.435922
# 31  32                      Ross St & Fourth Ave           15  40.437701
# 32  33             Schenley Dr & Schenley Dr Ext           19  40.442371
# 33  34               N Dithridge St & Centre Ave           19  40.451281
# 34  35                       Butler St & 36th St           15  40.465264
# 35  36                  Penn Ave & S Pacific Ave           15  40.464600
# 36  37                 S Negley Ave & Centre Ave           15  40.457316
# 37  38                Allequippa St & Darragh St           23  40.443591
# 38  39                   S 12th St & E Carson St           19  40.428600
# 39  40                         Penn Ave & 7th St           19  40.443310
# 40  41                     S 22nd St & Sidney St           19  40.429212
# 41  42                  Second Ave & Tecumseh St           19  40.408857
# 42  43                       Eliza St & Lytle St           15  40.413481
# 43  44                  Hamilton Ave & Fifth Ave           15  40.457570
# 44  45             N Braddock Ave & Hamilton Ave           15  40.453010
# 45  46               Bennett St & N Homewood Ave           15  40.456622
# 46  47                        17th St & Penn Ave           19  40.449626
# 47  48               Centre Ave & S Millvale Ave           19  40.453211
# 48  49                  Technology Dr & Bates St           23  40.430513
# 49  50                      Atwood St & Bates St           19  40.437987
# 50  51                  Coltart Ave & Forbes Ave           18  40.439012
# 51  52                   Bedford Ave & Memory Ln           19  40.448361
# 52  53                   Centre Ave & Heldman St           19  40.442841
# 53  54                   W Ohio St & Brighton Rd           19  40.452467
# 54  55            Brighton Rd & Pennsylvania Ave           19  40.456402
# 55  56                  Rosetta St & N Aiken Ave           15  40.467018
# 56  57                       52nd St & Butler St           19  40.480283
# 57  58                  W North Ave & Federal St           19  40.455268
# 58  59       Forbes Ave at TCS Hall (CMU Campus)           19  40.444654
# 59  60                   Wilkinsburg Park & Ride           19  40.446908
#
#     Longitude
# 0  -79.932331
# 1  -79.953400
# 2  -79.978300
# 3  -79.980000
# 4  -80.018007
# 5  -79.996074
# 6  -79.945204
# 7  -80.003000
# 8  -79.995106
# 9  -79.956827
# 10 -79.947507
# 11 -79.957118
# 12 -79.955764
# 13 -79.897544
# 14 -79.932253
# 15 -79.915300
# 16 -79.950868
# 17 -79.983300
# 18 -79.960380
# 19 -79.951900
# 20 -80.004800
# 21 -80.003312
# 22 -80.009100
# 23 -79.968300
# 24 -79.925700
# 25 -79.966296
# 26 -80.004700
# 27 -79.957600
# 28 -79.951083
# 29 -79.921996
# 30 -79.997551
# 31 -79.996481
# 32 -79.951688
# 33 -79.952982
# 34 -79.965652
# 35 -79.939900
# 36 -79.934331
# 37 -79.965456
# 38 -79.986371
# 39 -79.999996
# 40 -79.974535
# 41 -79.943684
# 42 -79.948254
# 43 -79.909952
# 44 -79.891204
# 45 -79.897503
# 46 -79.985918
# 47 -79.947761
# 48 -79.959989
# 49 -79.953705
# 50 -79.960292
# 51 -79.978268
# 52 -79.981616
# 53 -80.013872
# 54 -80.015393
# 55 -79.935232
# 56 -79.954287
# 57 -80.007123
# 58 -79.947535
# 59 -79.888645

# %%
# Assigns each POGOH station into a neighborhood
import pandas as pd
pogoh = pd.read_csv('pogoh.tsv',sep='\t')
northOakland = []
centralOakland = []
westOakland = []
southOakland = []
shadyside = []
stripDistrict = []
downtown = []
southside = []
northside = []
squirrelHill = []
eastLiberty = []
wilkinsburg = []
lawrenceville = []
bloomfield = []
greenfield = []
hazelwood = []
hillDistrict = []
other = []
def assignNeighborhood(name):    
    name = name.lower()
    # North Oakland
    if any(x in name for x in ["n dithridge", "dithridge", "craig", "bayard", "filmore", "fifth ave", "n bellefield", "s bellefield", "centre & bellefield", "n oakland", "craig st"]):
        northOakland.append(name)

    # Central Oakland
    elif any(x in name for x in["forbes", "bouquet", "ohara", "schenley", "coltart", "university place", "sennott", "tcs hall", "atwood", "ruskin", "oakland ave"]):
        centralOakland.append(name)

    # South Oakland
    elif any(x in name for x in["bates", "zulema", "technology", "ward", "swinburne", "mackey", "dawson", "oakcliffe", "boquet", "s oakland"]):
        southOakland.append(name)

    # West Oakland
    elif any(x in name for x in["allequippa", "darragh", "parkview", "de soto", "terrence", "robinson", "mccormick", "west oakland"]):
        westOakland.append(name)
        
    # Southside
    elif any(x in name for x in ["sidney", "carson", "southside", "s 4th", "27th", "station square", "glasshouse"]):
        southside.append(name)

    # Shadyside
    elif any(x in name for x in ["walnut", "ellsworth", "ivy", "neville", "gross", "aiken", "summerlea", "rosetta", "centre & millvale"]):
        shadyside.append(name)

    # Squirrel Hill
    elif any(x in name for x in ["murray", "beacon", "wilkins ave", "forbes & murray"]):
        squirrelHill.append(name)

    # Strip District
    elif any(x in name for x in ["21st", "17th", "penn ave & 33rd", "penn ave & 34th", "7th", "strip district"]):
        stripDistrict.append(name)

    # Downtown
    elif any(x in name for x in ["market square", "stanwix", "first ave", "ross", "fourth ave", "penn ave & 10th"]):
        downtown.append(name)
        
    # East Liberty
    elif any(x in name for x in [
        "putnam", "bakery square", "negley", "pacific", "s pacific", "centre & negley", "tioga", "homewood", "hamilton", "bennett", "braddock", "n homewood"]):
        eastLiberty.append(name)

    # Northside
    elif any(x in name for x in ["federal", "ohio", "brighton", "allegheny station", "north shore", "w north ave"]):
        northside.append(name)
        
    # Lawrenceville
    elif any(x in name for x in["butler", "44th", "36th", "42nd", "friendship", "penn & 35th", "lawrenceville"]):
        lawrenceville.append(name)

    # Bloomfield
    elif any(x in name for x in [
        "liberty & gross", "liberty & millvale", "centre & millvale", "gross st", "bloomfield", "millvale", "friendship"]):
        bloomfield.append(name)
        
    # Wilkinsburg
    elif "wilkinsburg" in name or "park & ride" in name:
        wilkinsburg.append(name)
        
    # Greenfield
    elif any(x in name for x in [
        "swineburne", "lytle", "saline", "greenfield", "tecumseh", "eliza furnace", "second ave", "hazelwood", "murray hill", "bigelow"]):
        greenfield.append(name)

    # Hazelwood
    elif any(x in name for x in["tecumseh", "eliza furnace", "second ave", "hazelwood"]):
        hazelwood.append(name)
     
    elif "penn ave" in name:
        if any(x in name for x in ["10th", "stanwix", "market", "9th", "liberty"]):
            downtown.append(name)
        elif any(x in name for x in ["21st", "25th", "28th", "33rd", "35th", "40th"]):
            stripDistrict.append(name)
        elif any(x in name for x in ["whitfield", "putnam", "pacific", "negley"]):
            eastLiberty.append(name)
        elif any(x in name for x in ["gross", "millvale"]):
            bloomfield.append(name)
        else:
            centralOakland.append(name)
    
    elif "centre ave" in name:
        if any(x in name for x in ["addison", "heldman"]):
            hillDistrict.append(name)
        elif any(x in name for x in ["millvale", "gross", "aiken"]):
            bloomfield.append(name)
        elif any(x in name for x in ["negley", "bennett", "braddock", "tioga"]):
            eastLiberty.append(name)
        else:
            northOakland.append(name)
    else:
        other.append(name)

import pandas as pd
pogoh = pd.read_csv('pogoh.tsv',sep='\t')

pogoh['Name'].apply(assignNeighborhood)
neighborhoods = [
    ["North Oakland", northOakland],
    ["Central Oakland", centralOakland],
    ["South Oakland", southOakland],
    ["West Oakland", westOakland],
    ["Shadyside", shadyside],
    ["Southside", southside],
    ["Northside", northside],
    ["Squirrel Hill", squirrelHill],
    ["East Liberty", eastLiberty],
    ["Strip District", stripDistrict],
    ["Downtown", downtown],
    ["Wilkinsburg", wilkinsburg],
    ["Lawrenceville", lawrenceville],
    ["Bloomfield", bloomfield],
    ["Greenfield", greenfield],
    ["Hazelwood", hazelwood],
    ["Hill District", hillDistrict],
    ["Other", other]
]

maxCount = 0
bestNeighborhood = ""
for name, stations in neighborhoods:
    count = len(stations)
    if count > maxCount:
        maxCount = count
        bestNeighborhood = name

print(f"The neighborhood with the most POGOH stations is: {bestNeighborhood}")
print(f"Number of stations: {maxCount}")

print("\nStation counts by neighborhood:")
for name, stations in neighborhoods:
    print(f"{name}: {len(stations)}")
# Out:
# The neighborhood with the most POGOH stations is: Central Oakland
# Number of stations: 8
#
# Station counts by neighborhood:
# North Oakland: 4
# Central Oakland: 8
# South Oakland: 1
# West Oakland: 2
# Shadyside: 6
# Southside: 6
# Northside: 5
# Squirrel Hill: 0
# East Liberty: 7
# Strip District: 4
# Downtown: 5
# Wilkinsburg: 1
# Lawrenceville: 3
# Bloomfield: 1
# Greenfield: 3
# Hazelwood: 0
# Hill District: 2
# Other: 2

# %%
import matplotlib.pyplot as plt
import pandas as pd
pogoh = pd.read_csv("pogoh.tsv",sep='\t')
data = {
    "Neighborhood": [
        "North Oakland", "Central Oakland", "South Oakland", "West Oakland",
        "Shadyside", "Southside", "Northside", "Squirrel Hill",
        "East Liberty", "Strip District", "Downtown", "Wilkinsburg",
        "Lawrenceville", "Bloomfield", "Greenfield", "Hazelwood",
        "Hill District", "Other"
    ],
    "Station Count": [
        4, 8, 1, 2, 6, 6, 5, 0, 7, 4, 5, 1, 3, 1, 3, 0, 2, 2
    ]
}

df = pd.DataFrame(data)
df = df.sort_values("Station Count", ascending=False)


# Plot
plt.figure(figsize=(10, 6))
plt.bar(df["Neighborhood"], df["Station Count"], color="blue")
plt.xticks(rotation=45, ha='right')
plt.xlabel("Neighborhood")
plt.ylabel("Number of Stations")
plt.title("Number of Stations per Pittsburgh Neighborhood")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The data clearly shows that Central Oakland is the best neighborhood when measured via accessbility. They have the most easy access to sustainable and eco friendly self-transportation.
# The data show that they have at least 10 POGOH station locations (there could be more added as POGOH continues to expand and the dataset is consistently updated)
# and among these stations, a total of 297 individual bike docks. This could be for several reasons:
# 1) Oakland is one of the largest and most populated neighborhoods in Pittsburgh so it makes sense that there should be more POGOH locations.
# 2) A majority of Central Oakland is resided by students, as it is home to several universities. POGOH bikes are a great mode of transportation because they are convenient, affordable, easily accessible, and eco-friendly.
# 3) Many station locations lie on borders between neighborhoods, so it can be subjective where a station actually is and what neighborhood it's considered a part of, potentially resulting in skewed data.
#
# My personal favorite neighborhood is the Strip District because there is so much to do and see. It is home to unique shops and restaurants of all time and fully embraces the Pittsburgh culture. However, it would make sense that the data does not show it to be the best based on our metric because it is a very distinct, less relevant neighborhood when it comes to local and student life over tourism. It has a less significant residential population and is more so known for exploration rather than practicality, which could show why it is a student's favorite instead of the data's, who is measuring sustainability. I still think that Central Oakland is a great neighborhood for many reasons!
